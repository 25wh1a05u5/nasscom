# %%
import random
import datetime

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Motion_Sensor']
LOCATIONS = ['Warehouse_A', 'Warehouse_B', 'Office_1', 'Office_2', 'Server_Room']
READING_RANGES = {
    'Temperature_Sensor': (15.0, 35.0),
    'Humidity_Sensor': (20.0, 90.0),
    'Pressure_Sensor': (980.0, 1050.0),
    'Motion_Sensor': (0.0, 1.0)
}

raw_sensor_data = []
start_time = datetime.datetime(2025, 1, 1, 0, 0, 0)

for i in range(1, 101):
    timestamp_str = (start_time + datetime.timedelta(minutes=i * 15)).strftime('%Y-%m-%d %H:%M:%S')
    device_id = f"DEV{i:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)
    raw_sensor_data.append((timestamp_str, device_id, device_type, location, value))

print("Task 1.1")
print(raw_sensor_data)
# Out:
# Task 1.1
# [('2025-01-01 00:15:00', 'DEV001', 'Motion_Sensor', 'Warehouse_B', 0.65), ('2025-01-01 00:30:00', 'DEV002', 'Temperature_Sensor', 'Warehouse_B', 28.74), ('2025-01-01 00:45:00', 'DEV003', 'Motion_Sensor', 'Office_1', 0.94), ('2025-01-01 01:00:00', 'DEV004', 'Temperature_Sensor', 'Warehouse_B', 24.11), ('2025-01-01 01:15:00', 'DEV005', 'Motion_Sensor', 'Server_Room', 0.37), ('2025-01-01 01:30:00', 'DEV006', 'Motion_Sensor', 'Warehouse_A', 0.03), ('2025-01-01 01:45:00', 'DEV007', 'Pressure_Sensor', 'Office_2', 1045.38), ('2025-01-01 02:00:00', 'DEV008', 'Humidity_Sensor', 'Warehouse_A', 76.0), ('2025-01-01 02:15:00', 'DEV009', 'Temperature_Sensor', 'Office_1', 21.58), ('2025-01-01 02:30:00', 'DEV010', 'Motion_Sensor', 'Warehouse_B', 0.04), ('2025-01-01 02:45:00', 'DEV011', 'Pressure_Sensor', 'Office_1', 981.67), ('2025-01-01 03:00:00', 'DEV012', 'Humidity_Sensor', 'Office_2', 67.15), ('2025-01-01 03:15:00', 'DEV013', 'Pressure_Sensor', 'Warehouse_A', 983.61), ('2025-01-01 03:30:00', 'DEV014', 'Pressure_Sensor', 'Server_Room', 1033.73), ('2025-01-01 03:45:00', 'DEV015', 'Pressure_Sensor', 'Office_1', 992.84), ('2025-01-01 04:00:00', 'DEV016', 'Pressure_Sensor', 'Warehouse_B', 1044.74), ('2025-01-01 04:15:00', 'DEV017', 'Pressure_Sensor', 'Office_1', 1024.69), ('2025-01-01 04:30:00', 'DEV018', 'Humidity_Sensor', 'Warehouse_B', 76.13), ('2025-01-01 04:45:00', 'DEV019', 'Temperature_Sensor', 'Office_1', 24.54), ('2025-01-01 05:00:00', 'DEV020', 'Motion_Sensor', 'Server_Room', 0.03), ('2025-01-01 05:15:00', 'DEV021', 'Motion_Sensor', 'Server_Room', 0.52), ('2025-01-01 05:30:00', 'DEV022', 'Humidity_Sensor', 'Office_2', 25.49), ('2025-01-01 05:45:00', 'DEV023', 'Temperature_Sensor', 'Office_2', 31.96), ('2025-01-01 06:00:00', 'DEV024', 'Motion_Sensor', 'Warehouse_A', 0.94), ('2025-01-01 06:15:00', 'DEV025', 'Motion_Sensor', 'Warehouse_B', 0.63), ('2025-01-01 06:30:00', 'DEV026', 'Humidity_Sensor', 'Office_2', 69.47), ('2025-01-01 06:45:00', 'DEV027', 'Motion_Sensor', 'Warehouse_B', 0.52), ('2025-01-01 07:00:00', 'DEV028', 'Temperature_Sensor', 'Warehouse_B', 16.77), ('2025-01-01 07:15:00', 'DEV029', 'Humidity_Sensor', 'Warehouse_A', 39.86), ('2025-01-01 07:30:00', 'DEV030', 'Humidity_Sensor', 'Warehouse_B', 86.05), ('2025-01-01 07:45:00', 'DEV031', 'Motion_Sensor', 'Warehouse_A', 0.76), ('2025-01-01 08:00:00', 'DEV032', 'Motion_Sensor', 'Warehouse_B', 0.09), ('2025-01-01 08:15:00', 'DEV033', 'Humidity_Sensor', 'Warehouse_A', 62.58), ('2025-01-01 08:30:00', 'DEV034', 'Humidity_Sensor', 'Office_1', 66.98), ('2025-01-01 08:45:00', 'DEV035', 'Temperature_Sensor', 'Office_1', 18.81), ('2025-01-01 09:00:00', 'DEV036', 'Pressure_Sensor', 'Warehouse_B', 1039.06), ('2025-01-01 09:15:00', 'DEV037', 'Humidity_Sensor', 'Office_1', 81.16), ('2025-01-01 09:30:00', 'DEV038', 'Pressure_Sensor', 'Office_1', 1007.72), ('2025-01-01 09:45:00', 'DEV039', 'Motion_Sensor', 'Office_1', 0.25), ('2025-01-01 10:00:00', 'DEV040', 'Motion_Sensor', 'Warehouse_B', 0.51), ('2025-01-01 10:15:00', 'DEV041', 'Humidity_Sensor', 'Office_1', 44.84), ('2025-01-01 10:30:00', 'DEV042', 'Humidity_Sensor', 'Office_1', 35.17), ('2025-01-01 10:45:00', 'DEV043', 'Motion_Sensor', 'Warehouse_A', 0.35), ('2025-01-01 11:00:00', 'DEV044', 'Temperature_Sensor', 'Office_1', 25.78), ('2025-01-01 11:15:00', 'DEV045', 'Humidity_Sensor', 'Office_2', 87.74), ('2025-01-01 11:30:00', 'DEV046', 'Pressure_Sensor', 'Warehouse_B', 999.12), ('2025-01-01 11:45:00', 'DEV047', 'Pressure_Sensor', 'Warehouse_B', 1006.24), ('2025-01-01 12:00:00', 'DEV048', 'Pressure_Sensor', 'Office_2', 1034.9), ('2025-01-01 12:15:00', 'DEV049', 'Motion_Sensor', 'Warehouse_B', 0.19), ('2025-01-01 12:30:00', 'DEV050', 'Humidity_Sensor', 'Server_Room', 53.7), ('2025-01-01 12:45:00', 'DEV051', 'Humidity_Sensor', 'Warehouse_A', 86.13), ('2025-01-01 13:00:00', 'DEV052', 'Motion_Sensor', 'Warehouse_A', 0.86), ('2025-01-01 13:15:00', 'DEV053', 'Pressure_Sensor', 'Office_1', 1021.31), ('2025-01-01 13:30:00', 'DEV054', 'Temperatur ...

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading
    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

print("Task 1.2")
print(temperature_readings)
# Out:
# Task 1.2
# [{'timestamp': '2025-01-01 00:30:00', 'device_id': 'DEV002', 'location': 'Warehouse_B', 'temperature_celsius': 28.74}, {'timestamp': '2025-01-01 01:00:00', 'device_id': 'DEV004', 'location': 'Warehouse_B', 'temperature_celsius': 24.11}, {'timestamp': '2025-01-01 02:15:00', 'device_id': 'DEV009', 'location': 'Office_1', 'temperature_celsius': 21.58}, {'timestamp': '2025-01-01 04:45:00', 'device_id': 'DEV019', 'location': 'Office_1', 'temperature_celsius': 24.54}, {'timestamp': '2025-01-01 05:45:00', 'device_id': 'DEV023', 'location': 'Office_2', 'temperature_celsius': 31.96}, {'timestamp': '2025-01-01 07:00:00', 'device_id': 'DEV028', 'location': 'Warehouse_B', 'temperature_celsius': 16.77}, {'timestamp': '2025-01-01 08:45:00', 'device_id': 'DEV035', 'location': 'Office_1', 'temperature_celsius': 18.81}, {'timestamp': '2025-01-01 11:00:00', 'device_id': 'DEV044', 'location': 'Office_1', 'temperature_celsius': 25.78}, {'timestamp': '2025-01-01 13:30:00', 'device_id': 'DEV054', 'location': 'Warehouse_B', 'temperature_celsius': 20.58}, {'timestamp': '2025-01-01 13:45:00', 'device_id': 'DEV055', 'location': 'Office_2', 'temperature_celsius': 28.89}, {'timestamp': '2025-01-01 17:00:00', 'device_id': 'DEV068', 'location': 'Warehouse_A', 'temperature_celsius': 30.24}, {'timestamp': '2025-01-01 18:15:00', 'device_id': 'DEV073', 'location': 'Office_1', 'temperature_celsius': 15.07}, {'timestamp': '2025-01-01 18:45:00', 'device_id': 'DEV075', 'location': 'Server_Room', 'temperature_celsius': 18.67}, {'timestamp': '2025-01-01 19:30:00', 'device_id': 'DEV078', 'location': 'Office_2', 'temperature_celsius': 29.64}, {'timestamp': '2025-01-01 22:15:00', 'device_id': 'DEV089', 'location': 'Server_Room', 'temperature_celsius': 23.76}, {'timestamp': '2025-01-01 22:30:00', 'device_id': 'DEV090', 'location': 'Warehouse_B', 'temperature_celsius': 20.5}, {'timestamp': '2025-01-02 00:00:00', 'device_id': 'DEV096', 'location': 'Warehouse_B', 'temperature_celsius': 23.44}, {'timestamp': '2025-01-02 00:30:00', 'device_id': 'DEV098', 'location': 'Warehouse_A', 'temperature_celsius': 33.53}, {'timestamp': '2025-01-02 00:45:00', 'device_id': 'DEV099', 'location': 'Office_1', 'temperature_celsius': 27.54}, {'timestamp': '2025-01-02 01:00:00', 'device_id': 'DEV100', 'location': 'Office_1', 'temperature_celsius': 24.54}]

# %%
unique_locations = {reading[3] for reading in raw_sensor_data}

print("Task 1.3")
print(unique_locations)
# Out:
# Task 1.3
# {'Server_Room', 'Warehouse_B', 'Office_1', 'Office_2', 'Warehouse_A'}

# %%
device_stats = {}

for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    current_min, current_max = device_stats[device_type]
    device_stats[device_type] = (min(current_min, value), max(current_max, value))

print("Task 1.4")
print(device_stats)
# Out:
# Task 1.4
# {'Temperature_Sensor': (15.07, 33.53), 'Humidity_Sensor': (20.08, 87.74), 'Pressure_Sensor': (981.67, 1045.38), 'Motion_Sensor': (0.02, 0.94)}

# %%
def get_readings_by_location(readings_list, target_location):
    return [reading for reading in readings_list if reading[3] == target_location]

sample_location = raw_sensor_data[0][3]
result_2_1 = get_readings_by_location(raw_sensor_data, sample_location)

print("Task 2.1")
for reading in result_2_1:
    print(reading)
# Out:
# Task 2.1
# ('2025-01-01 00:15:00', 'DEV001', 'Motion_Sensor', 'Warehouse_B', 0.65)
# ('2025-01-01 00:30:00', 'DEV002', 'Temperature_Sensor', 'Warehouse_B', 28.74)
# ('2025-01-01 01:00:00', 'DEV004', 'Temperature_Sensor', 'Warehouse_B', 24.11)
# ('2025-01-01 02:30:00', 'DEV010', 'Motion_Sensor', 'Warehouse_B', 0.04)
# ('2025-01-01 04:00:00', 'DEV016', 'Pressure_Sensor', 'Warehouse_B', 1044.74)
# ('2025-01-01 04:30:00', 'DEV018', 'Humidity_Sensor', 'Warehouse_B', 76.13)
# ('2025-01-01 06:15:00', 'DEV025', 'Motion_Sensor', 'Warehouse_B', 0.63)
# ('2025-01-01 06:45:00', 'DEV027', 'Motion_Sensor', 'Warehouse_B', 0.52)
# ('2025-01-01 07:00:00', 'DEV028', 'Temperature_Sensor', 'Warehouse_B', 16.77)
# ('2025-01-01 07:30:00', 'DEV030', 'Humidity_Sensor', 'Warehouse_B', 86.05)
# ('2025-01-01 08:00:00', 'DEV032', 'Motion_Sensor', 'Warehouse_B', 0.09)
# ('2025-01-01 09:00:00', 'DEV036', 'Pressure_Sensor', 'Warehouse_B', 1039.06)
# ('2025-01-01 10:00:00', 'DEV040', 'Motion_Sensor', 'Warehouse_B', 0.51)
# ('2025-01-01 11:30:00', 'DEV046', 'Pressure_Sensor', 'Warehouse_B', 999.12)
# ('2025-01-01 11:45:00', 'DEV047', 'Pressure_Sensor', 'Warehouse_B', 1006.24)
# ('2025-01-01 12:15:00', 'DEV049', 'Motion_Sensor', 'Warehouse_B', 0.19)
# ('2025-01-01 13:30:00', 'DEV054', 'Temperature_Sensor', 'Warehouse_B', 20.58)
# ('2025-01-01 16:15:00', 'DEV065', 'Motion_Sensor', 'Warehouse_B', 0.16)
# ('2025-01-01 17:15:00', 'DEV069', 'Pressure_Sensor', 'Warehouse_B', 1002.46)
# ('2025-01-01 17:45:00', 'DEV071', 'Motion_Sensor', 'Warehouse_B', 0.18)
# ('2025-01-01 18:00:00', 'DEV072', 'Pressure_Sensor', 'Warehouse_B', 1035.46)
# ('2025-01-01 19:15:00', 'DEV077', 'Motion_Sensor', 'Warehouse_B', 0.82)
# ('2025-01-01 22:30:00', 'DEV090', 'Temperature_Sensor', 'Warehouse_B', 20.5)
# ('2025-01-01 23:45:00', 'DEV095', 'Humidity_Sensor', 'Warehouse_B', 39.52)
# ('2025-01-02 00:00:00', 'DEV096', 'Temperature_Sensor', 'Warehouse_B', 23.44)
# ('2025-01-02 00:15:00', 'DEV097', 'Pressure_Sensor', 'Warehouse_B', 989.41)

# %%
def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = sum(item["temperature_celsius"] for item in temp_data_list)
    return total / len(temp_data_list)

average_temp = calculate_average_temperature(temperature_readings)

print("Task 2.2")
print("Average Temperature:", average_temp)
# Out:
# Task 2.2
# Average Temperature: 24.4345

# %%
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"
    )

print("Task 2.3")

for reading in temperature_readings:
    print(generate_report_line(reading))
# Out:
# Task 2.3
# [2025-01-01 00:30:00] Device DEV002 at Warehouse_B: 28.74°C
# [2025-01-01 01:00:00] Device DEV004 at Warehouse_B: 24.11°C
# [2025-01-01 02:15:00] Device DEV009 at Office_1: 21.58°C
# [2025-01-01 04:45:00] Device DEV019 at Office_1: 24.54°C
# [2025-01-01 05:45:00] Device DEV023 at Office_2: 31.96°C
# [2025-01-01 07:00:00] Device DEV028 at Warehouse_B: 16.77°C
# [2025-01-01 08:45:00] Device DEV035 at Office_1: 18.81°C
# [2025-01-01 11:00:00] Device DEV044 at Office_1: 25.78°C
# [2025-01-01 13:30:00] Device DEV054 at Warehouse_B: 20.58°C
# [2025-01-01 13:45:00] Device DEV055 at Office_2: 28.89°C
# [2025-01-01 17:00:00] Device DEV068 at Warehouse_A: 30.24°C
# [2025-01-01 18:15:00] Device DEV073 at Office_1: 15.07°C
# [2025-01-01 18:45:00] Device DEV075 at Server_Room: 18.67°C
# [2025-01-01 19:30:00] Device DEV078 at Office_2: 29.64°C
# [2025-01-01 22:15:00] Device DEV089 at Server_Room: 23.76°C
# [2025-01-01 22:30:00] Device DEV090 at Warehouse_B: 20.5°C
# [2025-01-02 00:00:00] Device DEV096 at Warehouse_B: 23.44°C
# [2025-01-02 00:30:00] Device DEV098 at Warehouse_A: 33.53°C
# [2025-01-02 00:45:00] Device DEV099 at Office_1: 27.54°C
# [2025-01-02 01:00:00] Device DEV100 at Office_1: 24.54°C

# %%
import os

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print("Task 3.1")
    print("Directory created")
else:
    print("Task 3.1")
    print("Directory already exists")
# Out:
# Task 3.1
# Directory already exists

# %%
import datetime

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print("Task 3.2")
    print(days, "days")
    print(hours, "hours")
    print(minutes, "minutes")
else:
    print("Not enough data")
# Out:
# Task 3.2
# 1 days
# 0 hours
# 45 minutes

# %%
import random

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("Task 3.3")

for value in random_values:
    print(value)
# Out:
# Task 3.3
# 186
# 186
# 148
# 162
# 113

# %%
report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as f:
        for reading in temperature_readings:
            line = generate_report_line(reading)
            f.write(line + "\n")

    print("Task 4.1")
    print("Report written successfully")

except IOError as e:
    print(e)
# Out:
# Task 4.1
# Report written successfully

# %%
read_report_lines = []

try:
    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()

    print("Task 4.2")

    for line in read_report_lines:
        print(line.strip())

except IOError as e:
    print(e)
# Out:
# Task 4.2
# [2025-01-01 00:30:00] Device DEV002 at Warehouse_B: 28.74°C
# [2025-01-01 01:00:00] Device DEV004 at Warehouse_B: 24.11°C
# [2025-01-01 02:15:00] Device DEV009 at Office_1: 21.58°C
# [2025-01-01 04:45:00] Device DEV019 at Office_1: 24.54°C
# [2025-01-01 05:45:00] Device DEV023 at Office_2: 31.96°C
# [2025-01-01 07:00:00] Device DEV028 at Warehouse_B: 16.77°C
# [2025-01-01 08:45:00] Device DEV035 at Office_1: 18.81°C
# [2025-01-01 11:00:00] Device DEV044 at Office_1: 25.78°C
# [2025-01-01 13:30:00] Device DEV054 at Warehouse_B: 20.58°C
# [2025-01-01 13:45:00] Device DEV055 at Office_2: 28.89°C
# [2025-01-01 17:00:00] Device DEV068 at Warehouse_A: 30.24°C
# [2025-01-01 18:15:00] Device DEV073 at Office_1: 15.07°C
# [2025-01-01 18:45:00] Device DEV075 at Server_Room: 18.67°C
# [2025-01-01 19:30:00] Device DEV078 at Office_2: 29.64°C
# [2025-01-01 22:15:00] Device DEV089 at Server_Room: 23.76°C
# [2025-01-01 22:30:00] Device DEV090 at Warehouse_B: 20.5°C
# [2025-01-02 00:00:00] Device DEV096 at Warehouse_B: 23.44°C
# [2025-01-02 00:30:00] Device DEV098 at Warehouse_A: 33.53°C
# [2025-01-02 00:45:00] Device DEV099 at Office_1: 27.54°C
# [2025-01-02 01:00:00] Device DEV100 at Office_1: 24.54°C
